# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Question 5
def my_lin_regression(f, x, y):
    n = len(f)
    A = np.array([f[i](x) for i in range(n)]).T
    # Adding constant function to the basis in order to balance the 'noise'
    # Note that, since we add constant function anyways,
    # the basis (f) need not contain the constant function.
    A = np.concatenate((A,np.ones((len(x),1))), axis = 1)
    y = y[:, np.newaxis]
    beta = np.linalg.pinv(A).dot(y)
    return beta

# %%
x = np.linspace(0, 2*np.pi, 1000)
y = 3*np.sin(x) - 2*np.cos(x) + np.random.random(len(x))
f = [np.sin, np.cos]
beta = my_lin_regression(f, x, y)


plt.figure(figsize = (10,8))
plt.plot(x,y,"b.", label = "data")
plt.plot(x, beta[0]*f[0](x)+beta[1]*f[1](x)+beta[2], "r", label="regression")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Least Square Regression Example")
plt.legend()
plt.show()

# %%
x = np.linspace(0, 2, 1000)
y = 5*x**2 - 7*x + 2*np.random.random(len(x)) + 3
f = [lambda x: x**2, lambda x: x]
beta = my_lin_regression(f, x, y)
plt.figure(figsize = (10,8))
plt.plot(x,y,"c.", label = "data")
plt.plot(x, beta[0]*f[0](x)+beta[1]*f[1](x)+ beta[2], "k", label="regression")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Least Square Regression Example")
plt.legend()
plt.show()

# %%
# Question 6
def my_exp_regression (x,y):
    A = np.vstack([np.ones(len(x)), x]).T
    y = y[:, np.newaxis]
    coeff = np.linalg.pinv(A).dot(np.log(y))
    return np.exp(coeff[0]), coeff[1]

# %%
x = np.linspace(0, 1, 1000)
y = 2*np.exp(-0.5*x) + 0.25*np.random.random(len(x))
alpha, beta = my_exp_regression(x, y)

plt.figure(figsize = (10,8))
plt.plot(x,y,"b.", label = "data")
plt.plot(x, alpha*np.exp(beta*x), "r", label="regression")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Least Square Regression on Exponential Model")
plt.legend()
plt.show()

# %%
x = np.linspace(0, 1, 1000)
y = 1.7*np.exp(0.6*x) + 0.25*np.random.random(len(x))
alpha, beta = my_exp_regression(x, y)

plt.figure(figsize = (10,8))
plt.plot(x,y,"g.", label = "data")
plt.plot(x, alpha*np.exp(beta*x), "m", label="regression")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Least Square Regression on Exponential Model")
plt.legend()
plt.show()
